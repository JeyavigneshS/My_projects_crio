# %%
import pandas as pd
import inspect

# %%
import pandas as pd

def drop_missing_vehicle_data(df):
    """
    Drops rows where both 'License Plate' and 'Registration Date' are missing in the DataFrame.

    Parameters:
        df (pd.DataFrame): The input DataFrame containing vehicle registration information.

    Returns:
        pd.DataFrame: DataFrame with rows removed where both 'License Plate' and 'Registration Date' are NaN.
    """
    # Print the original DataFrame
    print("Original DataFrame:")
    print(df)

    # Drop rows where both 'License Plate' and 'Registration Date' are missing
    cleaned_df = df.dropna(subset=['License Plate', 'Registration Date'], how='all')

    # Print the cleaned DataFrame
    print("\nCleaned DataFrame:")
    print(cleaned_df)

    return cleaned_df
data = {
    'Owner Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace'],
    'License Plate': ['ABC123', None, 'XYZ987', None, 'LMN456', None, None],
    'Registration Date': ['2023-05-10', None, '2022-11-23', None, '2021-09-15', '2020-07-30', None]
}

df = pd.DataFrame(data)

drop_missing_vehicle_data(df)
# Out:
# Original DataFrame:
#   Owner Name License Plate Registration Date
# 0      Alice        ABC123        2023-05-10
# 1        Bob          None              None
# 2    Charlie        XYZ987        2022-11-23
# 3      David          None              None
# 4        Eve        LMN456        2021-09-15
# 5      Frank          None        2020-07-30
# 6      Grace          None              None
#
# Cleaned DataFrame:
#   Owner Name License Plate Registration Date
# 0      Alice        ABC123        2023-05-10
# 2    Charlie        XYZ987        2022-11-23
# 4        Eve        LMN456        2021-09-15
# 5      Frank          None        2020-07-30
#   Owner Name License Plate Registration Date
# 0      Alice        ABC123        2023-05-10
# 2    Charlie        XYZ987        2022-11-23
# 4        Eve        LMN456        2021-09-15
# 5      Frank          None        2020-07-30

# %%
# Do not edit this cell
def test_drop_missing_vehicle_data():
    """Test if rows with missing 'License Plate' and 'Registration Date' are correctly removed from the DataFrame."""
    # Check if df.dropna() is used in the function
    source_code = inspect.getsource(drop_missing_vehicle_data)
    assert "dropna" in source_code, "df.dropna() is not used in the function"

    # Create a test DataFrame
    test_data = {
        'Owner Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace'],
        'License Plate': ['ABC123', None, 'XYZ987', None, 'LMN456', None, None],
        'Registration Date': ['2023-05-10', None, '2022-11-23', None, '2021-09-15', '2020-07-30', None]
    }
    test_df = pd.DataFrame(test_data)

    # Get function results
    result_df = drop_missing_vehicle_data(test_df)

    # Check if the function returns a DataFrame
    assert isinstance(result_df, pd.DataFrame), "Function did not return a DataFrame"

    # Check if the correct rows were removed
    expected_remaining_names = ['Alice', 'Charlie', 'Eve', 'Frank']
    assert list(result_df['Owner Name']) == expected_remaining_names, "Rows were not correctly removed"

    print("✅ Test Passed: drop_missing_vehicle_data() is implemented correctly.")

# Run the test
test_drop_missing_vehicle_data()
# Out:
# Original DataFrame:
#   Owner Name License Plate Registration Date
# 0      Alice        ABC123        2023-05-10
# 1        Bob          None              None
# 2    Charlie        XYZ987        2022-11-23
# 3      David          None              None
# 4        Eve        LMN456        2021-09-15
# 5      Frank          None        2020-07-30
# 6      Grace          None              None
#
# Cleaned DataFrame:
#   Owner Name License Plate Registration Date
# 0      Alice        ABC123        2023-05-10
# 2    Charlie        XYZ987        2022-11-23
# 4        Eve        LMN456        2021-09-15
# 5      Frank          None        2020-07-30
# ✅ Test Passed: drop_missing_vehicle_data() is implemented correctly.
